# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("train-data.csv")
df
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 72000       CNG       Manual      First  26.6 km/kg
# 1                 41000    Diesel       Manual      First  19.67 kmpl
# 2                 46000    Petrol       Manual      First   18.2 kmpl
# 3                 87000    Diesel       Manual      First  20.77 kmpl
# 4                 40670    Diesel    Automatic     Second   15.2 kmpl
# ...                 ...       ...          ...        ...         ...
# 6014              27365    Diesel       Manual      First   28.4 kmpl
# 6015             100000    Diesel       Manual      First   24.4 kmpl
# 6016              55000    Diesel       Manual     Second   14.0 kmpl
# 6017              46000    Petrol       Manual      First   18.9 kmpl
# 6018              47000    Diesel       Manual      First  25.44 kmpl
#
#        Engine      Power  Seats  New_Price  Price
# 0      998 CC  58.16 bhp    5.0        NaN   1.75
# 1     1582 CC  126.2 bhp    5.0        NaN  12.50
# 2     1199 CC   88.7 bhp    5.0  8.61 Lakh   4.50
# 3     1248 CC  88.76 bhp    7.0        NaN   6.00
# 4     1968 CC  140.8 bhp    5.0        NaN  17.74
# ...       ...        ...    ...        ...    ...
# 6014  1248 CC     74 bhp    5.0  7.88 Lakh   4.75
# 6015  1120 CC     71 bhp    5.0        NaN   4.00
# 6016  2498 CC    112 bhp    8.0        NaN   2.90
# 6017   998 CC   67.1 bhp    5.0        NaN   2.65
# 6018   936 CC   57.6 bhp    5.0        NaN   2.50
#
# [6019 rows x 14 columns]

# %%
df.shape
# Out:
# (6019, 14)

# %%
df.drop(["Unnamed: 0","New_Price"],axis=1,inplace=True)
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
#      Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0          CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1       Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2       Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3       Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4       Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
# ...        ...          ...        ...         ...      ...        ...    ...
# 6014    Diesel       Manual      First   28.4 kmpl  1248 CC     74 bhp    5.0
# 6015    Diesel       Manual      First   24.4 kmpl  1120 CC     71 bhp    5.0
# 6016    Diesel       Manual     Second   14.0 kmpl  2498 CC    112 bhp    8.0
# 6017    Petrol       Manual      First   18.9 kmpl   998 CC   67.1 bhp    5.0
# 6018    Diesel       Manual      First  25.44 kmpl   936 CC   57.6 bhp    5.0
#
#       Price
# 0      1.75
# 1     12.50
# 2      4.50
# 3      6.00
# 4     17.74
# ...     ...
# 6014   4.75
# 6015   4.00
# 6016   2.90
# 6017   2.65
# 6018   2.50
#
# [6019 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# Name                  0
# Location              0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage               2
# Engine               36
# Power                36
# Seats                42
# Price                 0
# dtype: int64

# %%
plt.figure(figsize=(7,5))
sns.heatmap(df.isnull())
plt.show()

# %%
df['Location'].value_counts()
# Out:
# Mumbai        790
# Hyderabad     742
# Kochi         651
# Coimbatore    636
# Pune          622
# Delhi         554
# Kolkata       535
# Chennai       494
# Jaipur        413
# Bangalore     358
# Ahmedabad     224
# Name: Location, dtype: int64

# %%
df['Fuel_Type'].value_counts()
# Out:
# Diesel      3205
# Petrol      2746
# CNG           56
# LPG           10
# Electric       2
# Name: Fuel_Type, dtype: int64

# %%
df[(df['Fuel_Type']=='Electric') | (df['Fuel_Type']=='LPG')]
# Out:
#                                  Name   Location  Year  Kilometers_Driven  \
# 5     Hyundai EON LPG Era Plus Option  Hyderabad  2012              75000
# 936       Maruti Wagon R LXI LPG BSIV  Hyderabad  2012              72000
# 987      Maruti Wagon R LXI DUO BSIII     Mumbai  2008              64226
# 2278      Hyundai Santro Xing GLS LPG       Pune  2010              55000
# 2385      Hyundai Santro Xing GLS LPG  Hyderabad  2011              17000
# 2436            Hyundai i10 Magna LPG     Jaipur  2012              53000
# 2941  Hyundai Santro Xing GL Plus LPG  Hyderabad  2014              56000
# 3595      Maruti Wagon R LX DUO BSIII  Hyderabad  2007              65047
# 4446             Mahindra E Verito D4    Chennai  2016              50000
# 4904        Toyota Prius 2009-2016 Z4     Mumbai  2011              44000
# 5506      Maruti Wagon R Duo LX BSIII  Hyderabad  2012              72389
# 5997           Maruti Wagon R Duo Lxi     Jaipur  2010              70000
#
#      Fuel_Type Transmission Owner_Type      Mileage   Engine      Power  \
# 5          LPG       Manual      First   21.1 km/kg   814 CC   55.2 bhp
# 936        LPG       Manual      First   26.2 km/kg   998 CC   58.2 bhp
# 987        LPG       Manual      First   17.3 km/kg  1061 CC   57.5 bhp
# 2278       LPG       Manual     Second  13.45 km/kg  1086 CC   62.1 bhp
# 2385       LPG       Manual      First  13.45 km/kg  1086 CC   62.1 bhp
# 2436       LPG       Manual     Second   19.2 km/kg  1086 CC  68.05 bhp
# 2941       LPG       Manual      First  13.45 km/kg  1086 CC   62.1 bhp
# 3595       LPG       Manual      First   17.3 km/kg  1061 CC   57.5 bhp
# 4446  Electric    Automatic      First          NaN    72 CC     41 bhp
# 4904  Electric    Automatic      First          NaN  1798 CC     73 bhp
# 5506       LPG       Manual      First   26.2 km/kg   998 CC   58.2 bhp
# 5997       LPG       Manual      First   26.2 km/kg   998 CC   58.2 bhp
#
#       Seats  Price
# 5       5.0   2.35
# 936     5.0   2.85
# 987     5.0   1.45
# 2278    5.0   1.65
# 2385    5.0   3.10
# 2436    5.0   2.85
# 2941    5.0   3.20
# 3595    5.0   1.95
# 4446    5.0  13.00
# 4904    5.0  12.75
# 5506    5.0   3.20
# 5997    5.0   2.27

# %%
i =df[(df['Fuel_Type']=='LPG') | (df['Fuel_Type']=='Electric')].index
df.drop(i,axis=0,inplace=True)

# %%
df['Transmission'].value_counts()
# Out:
# Manual       4289
# Automatic    1718
# Name: Transmission, dtype: int64

# %%
df['Owner_Type'].value_counts()
# Out:
# First             4919
# Second             966
# Third              113
# Fourth & Above       9
# Name: Owner_Type, dtype: int64

# %%
i = df[df['Owner_Type']=='Fourth & Above'].index
df.drop(i,axis=0,inplace=True)

# %%
df['Seats'].value_counts()
# Out:
# 5.0     4998
# 7.0      672
# 8.0      132
# 4.0       99
# 6.0       31
# 2.0       16
# 10.0       5
# 9.0        3
# 0.0        1
# Name: Seats, dtype: int64

# %%
df[df['Seats']>8]
# Out:
#                                        Name   Location  Year  \
# 814                     Toyota Qualis FS B2       Pune  2004
# 917                            Tata Sumo DX     Mumbai  2013
# 1347              Mahindra Scorpio LX BS IV  Bangalore  2007
# 1907                    Toyota Qualis FS B3  Bangalore  2002
# 2267                    Toyota Qualis RS E2       Pune  2004
# 2312        Chevrolet Tavera LT 9 Str BS IV    Kolkata  2012
# 2359                  Mahindra Xylo D2 Maxx    Chennai  2016
# 2575  Chevrolet Tavera LS B3 10 Seats BSIII  Hyderabad  2015
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 814               77757    Diesel       Manual     Second   13.1 kmpl
# 917               20000    Diesel       Manual      First  14.07 kmpl
# 1347              74112    Diesel       Manual      First  12.05 kmpl
# 1907              63000    Diesel       Manual      Third   13.1 kmpl
# 2267             215750    Diesel       Manual     Second    0.0 kmpl
# 2312              67132    Diesel       Manual      First  13.58 kmpl
# 2359             150000    Diesel       Manual      First  14.95 kmpl
# 2575             120000    Diesel       Manual      First   14.8 kmpl
#
#        Engine     Power  Seats  Price
# 814   2446 CC    75 bhp   10.0   3.50
# 917   1978 CC  83.1 bhp   10.0   5.25
# 1347  2179 CC   120 bhp    9.0   4.10
# 1907  2446 CC    75 bhp   10.0   3.65
# 2267  2446 CC  null bhp   10.0   3.50
# 2312  2499 CC    78 bhp    9.0   4.75
# 2359  2489 CC  93.7 bhp    9.0   4.50
# 2575  2499 CC    80 bhp   10.0   5.50

# %%
df['Seats']=np.where(df['Seats']>8,6,df['Seats'])
df.drop(df[df['Seats']==0].index,axis=0,inplace=True)
df['Seats'].value_counts()
# Out:
# 5.0    4998
# 7.0     672
# 8.0     132
# 4.0      99
# 6.0      39
# 2.0      16
# Name: Seats, dtype: int64

# %%
df['Name'].value_counts()
# Out:
# Mahindra XUV500 W8 2WD                 49
# Maruti Swift VDI                       45
# Honda City 1.5 S MT                    34
# Maruti Swift Dzire VDI                 34
# Maruti Swift VDI BSIV                  31
#                                        ..
# Mahindra Scorpio S10 AT 4WD             1
# Hyundai i20 1.2 Era                     1
# Toyota Camry W4 (AT)                    1
# BMW 5 Series 2013-2017 520d M Sport     1
# Mahindra Xylo D4 BSIV                   1
# Name: Name, Length: 1862, dtype: int64

# %%
df['Name'].nunique()
# Out:
# 1862

# %%
df['Model']=df['Name'].map(lambda x: str(x).strip().split(" ")[1])
df['Name']=df['Name'].map(lambda x: str(x).strip().split(" ")[0])
df
# Out:
#            Name    Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0        Maruti      Mumbai  2010              72000       CNG       Manual
# 1       Hyundai        Pune  2015              41000    Diesel       Manual
# 2         Honda     Chennai  2011              46000    Petrol       Manual
# 3        Maruti     Chennai  2012              87000    Diesel       Manual
# 4          Audi  Coimbatore  2013              40670    Diesel    Automatic
# ...         ...         ...   ...                ...       ...          ...
# 6014     Maruti       Delhi  2014              27365    Diesel       Manual
# 6015    Hyundai      Jaipur  2015             100000    Diesel       Manual
# 6016   Mahindra      Jaipur  2012              55000    Diesel       Manual
# 6017     Maruti     Kolkata  2013              46000    Petrol       Manual
# 6018  Chevrolet   Hyderabad  2011              47000    Diesel       Manual
#
#      Owner_Type     Mileage   Engine      Power  Seats  Price   Model
# 0         First  26.6 km/kg   998 CC  58.16 bhp    5.0   1.75   Wagon
# 1         First  19.67 kmpl  1582 CC  126.2 bhp    5.0  12.50   Creta
# 2         First   18.2 kmpl  1199 CC   88.7 bhp    5.0   4.50    Jazz
# 3         First  20.77 kmpl  1248 CC  88.76 bhp    7.0   6.00  Ertiga
# 4        Second   15.2 kmpl  1968 CC  140.8 bhp    5.0  17.74      A4
# ...         ...         ...      ...        ...    ...    ...     ...
# 6014      First   28.4 kmpl  1248 CC     74 bhp    5.0   4.75   Swift
# 6015      First   24.4 kmpl  1120 CC     71 bhp    5.0   4.00   Xcent
# 6016     Second   14.0 kmpl  2498 CC    112 bhp    8.0   2.90    Xylo
# 6017      First   18.9 kmpl   998 CC   67.1 bhp    5.0   2.65   Wagon
# 6018      First  25.44 kmpl   936 CC   57.6 bhp    5.0   2.50    Beat
#
# [5997 rows x 13 columns]

# %%
df['Model'].value_counts()
# Out:
# Swift         351
# City          270
# i20           246
# Verna         170
# Innova        162
#              ...
# XUV300          1
# Fortwo          1
# Countryman      1
# Clubman         1
# F               1
# Name: Model, Length: 210, dtype: int64

# %%
df['Model'].value_counts()[df['Model'].value_counts()<5]
# Out:
# Avventura     4
# V40           4
# Hexa          4
# R-Class       4
# Tucson        4
#              ..
# XUV300        1
# Fortwo        1
# Countryman    1
# Clubman       1
# F             1
# Name: Model, Length: 75, dtype: int64

# %%
df['Year'].value_counts()
# Out:
# 2014    796
# 2015    744
# 2016    740
# 2013    649
# 2017    587
# 2012    575
# 2011    464
# 2010    339
# 2018    298
# 2009    197
# 2008    171
# 2007    122
# 2019    102
# 2006     77
# 2005     56
# 2004     31
# 2003     17
# 2002     15
# 2001      7
# 2000      4
# 1998      4
# 1999      2
# Name: Year, dtype: int64

# %%
df['Year']=df['Year'].astype(str)
df['Year']=np.where(df['Year'].astype(int)<2003,"less than 2003",df['Year'])
df['Year'].value_counts()
# Out:
# 2014              796
# 2015              744
# 2016              740
# 2013              649
# 2017              587
# 2012              575
# 2011              464
# 2010              339
# 2018              298
# 2009              197
# 2008              171
# 2007              122
# 2019              102
# 2006               77
# 2005               56
# less than 2003     32
# 2004               31
# 2003               17
# Name: Year, dtype: int64

# %%
df['Kilometers_Driven'].isnull().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# Name                  object
# Location              object
# Year                  object
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Engine                object
# Power                 object
# Seats                float64
# Price                float64
# Model                 object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Name                  0
# Location              0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage               0
# Engine               35
# Power                35
# Seats                41
# Price                 0
# Model                 0
# dtype: int64

# %%
df['Mileage'].unique
# Out:
# <bound method Series.unique of 0       26.6 km/kg
# 1       19.67 kmpl
# 2        18.2 kmpl
# 3       20.77 kmpl
# 4        15.2 kmpl
#            ...
# 6014     28.4 kmpl
# 6015     24.4 kmpl
# 6016     14.0 kmpl
# 6017     18.9 kmpl
# 6018    25.44 kmpl
# Name: Mileage, Length: 5997, dtype: object>

# %%
df['Mileage']=df['Mileage'].map(lambda x: str(x).strip().split(" ")[0])
df
# Out:
#            Name    Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0        Maruti      Mumbai  2010              72000       CNG       Manual
# 1       Hyundai        Pune  2015              41000    Diesel       Manual
# 2         Honda     Chennai  2011              46000    Petrol       Manual
# 3        Maruti     Chennai  2012              87000    Diesel       Manual
# 4          Audi  Coimbatore  2013              40670    Diesel    Automatic
# ...         ...         ...   ...                ...       ...          ...
# 6014     Maruti       Delhi  2014              27365    Diesel       Manual
# 6015    Hyundai      Jaipur  2015             100000    Diesel       Manual
# 6016   Mahindra      Jaipur  2012              55000    Diesel       Manual
# 6017     Maruti     Kolkata  2013              46000    Petrol       Manual
# 6018  Chevrolet   Hyderabad  2011              47000    Diesel       Manual
#
#      Owner_Type Mileage   Engine      Power  Seats  Price   Model
# 0         First    26.6   998 CC  58.16 bhp    5.0   1.75   Wagon
# 1         First   19.67  1582 CC  126.2 bhp    5.0  12.50   Creta
# 2         First    18.2  1199 CC   88.7 bhp    5.0   4.50    Jazz
# 3         First   20.77  1248 CC  88.76 bhp    7.0   6.00  Ertiga
# 4        Second    15.2  1968 CC  140.8 bhp    5.0  17.74      A4
# ...         ...     ...      ...        ...    ...    ...     ...
# 6014      First    28.4  1248 CC     74 bhp    5.0   4.75   Swift
# 6015      First    24.4  1120 CC     71 bhp    5.0   4.00   Xcent
# 6016     Second    14.0  2498 CC    112 bhp    8.0   2.90    Xylo
# 6017      First    18.9   998 CC   67.1 bhp    5.0   2.65   Wagon
# 6018      First   25.44   936 CC   57.6 bhp    5.0   2.50    Beat
#
# [5997 rows x 13 columns]

# %%
df['Mileage']=df['Mileage'].astype(float)

# %%
df['Engine'].unique
# Out:
# <bound method Series.unique of 0        998 CC
# 1       1582 CC
# 2       1199 CC
# 3       1248 CC
# 4       1968 CC
#          ...
# 6014    1248 CC
# 6015    1120 CC
# 6016    2498 CC
# 6017     998 CC
# 6018     936 CC
# Name: Engine, Length: 5997, dtype: object>

# %%
df['Engine'].unique
# Out:
# <bound method Series.unique of 0        998 CC
# 1       1582 CC
# 2       1199 CC
# 3       1248 CC
# 4       1968 CC
#          ...
# 6014    1248 CC
# 6015    1120 CC
# 6016    2498 CC
# 6017     998 CC
# 6018     936 CC
# Name: Engine, Length: 5997, dtype: object>

# %%
def fun(x):
    if x == None:
        return x
    elif len(str(x).split(" "))==2:
        return str(x).split(" ")[0]

# %%
df['Engine']=df['Engine'].apply(fun)
df['Engine'].isnull().sum()
# Out:
# 35

# %%
df['Engine']=df['Engine'].astype(float)

# %%
lst = df['Model'].unique()
for i in lst:
    mean_model = df[df["Model"]==i]['Engine'].mean()
    df.update(df[df['Model']==i]['Engine'].fillna(mean_model))

# %%
df['Power'].isnull().sum()
# Out:
# 35

# %%
df['Power'].unique
# Out:
# <bound method Series.unique of 0       58.16 bhp
# 1       126.2 bhp
# 2        88.7 bhp
# 3       88.76 bhp
# 4       140.8 bhp
#           ...
# 6014       74 bhp
# 6015       71 bhp
# 6016      112 bhp
# 6017     67.1 bhp
# 6018     57.6 bhp
# Name: Power, Length: 5997, dtype: object>

# %%
df['Power']=df['Power'].apply(fun)
df['Power'].unique
# Out:
# <bound method Series.unique of 0       58.16
# 1       126.2
# 2        88.7
# 3       88.76
# 4       140.8
#         ...
# 6014       74
# 6015       71
# 6016      112
# 6017     67.1
# 6018     57.6
# Name: Power, Length: 5997, dtype: object>

# %%
df[df['Power'].isnull()]
# Out:
#          Name    Location            Year  Kilometers_Driven Fuel_Type  \
# 194     Honda   Ahmedabad            2007              60006    Petrol
# 208    Maruti     Kolkata            2010              42001    Petrol
# 733    Maruti     Chennai            2006              97800    Petrol
# 749      Land      Mumbai            2008              55001    Diesel
# 1294    Honda       Delhi            2009              55005    Petrol
# 1327   Maruti   Hyderabad            2015              50295    Petrol
# 1385    Honda        Pune            2004             115000    Petrol
# 1460     Land  Coimbatore            2008              69078    Petrol
# 2074   Maruti        Pune            2011              24255    Petrol
# 2096  Hyundai  Coimbatore            2004              52146    Petrol
# 2264   Toyota        Pune            2012              24500    Petrol
# 2325   Maruti        Pune            2015              67000    Petrol
# 2335   Maruti      Mumbai            2007              55000    Petrol
# 2530      BMW       Kochi            2014              64158    Diesel
# 2542  Hyundai   Bangalore            2011              65000    Petrol
# 2623      BMW        Pune            2012              95000    Diesel
# 2668   Maruti     Kolkata            2014              32986    Petrol
# 2737   Maruti      Jaipur  less than 2003             200000    Petrol
# 2780  Hyundai        Pune            2009             100000    Petrol
# 2842  Hyundai   Bangalore            2012              43000    Petrol
# 3272      BMW      Mumbai            2008              81000    Diesel
# 3520      BMW       Delhi            2012              90000    Diesel
# 3522  Hyundai       Kochi            2012              66400    Petrol
# 3810    Honda     Kolkata            2013              27000    Petrol
# 4011     Fiat        Pune            2011              45271    Diesel
# 4152     Land      Mumbai            2003              75000    Diesel
# 4229  Hyundai   Bangalore            2005              79000    Petrol
# 4577      BMW       Delhi            2012              72000    Diesel
# 4604    Honda        Pune            2011              98000    Petrol
# 4697     Fiat       Kochi            2017              17941    Petrol
# 4712  Hyundai        Pune            2003              80000    Petrol
# 4952     Fiat     Kolkata            2010              47000    Petrol
# 5015   Maruti       Delhi            2006              63000    Petrol
# 5185   Maruti       Delhi            2012              52000    Petrol
# 5270    Honda   Bangalore  less than 2003              53000    Petrol
#
#      Transmission Owner_Type  Mileage       Engine Power  Seats  Price   Model
# 194        Manual      First     0.00  1494.718045  None    NaN   2.95    City
# 208        Manual      First    16.10  1240.447368  None    NaN   2.11   Swift
# 733        Manual      Third    16.10  1240.447368  None    NaN   1.75   Swift
# 749     Automatic     Second     0.00  2475.719298  None    NaN  26.50   Rover
# 1294       Manual      First    12.80  1494.718045  None    NaN   3.20    City
# 1327       Manual      First    16.10  1240.447368  None    NaN   5.80   Swift
# 1385       Manual     Second     0.00  1494.718045  None    NaN   1.50    City
# 1460       Manual      First     0.00  2475.719298  None    NaN  40.88   Rover
# 2074       Manual      First    16.10  1240.447368  None    NaN   3.15   Swift
# 2096       Manual      First     0.00  1077.044118  None    NaN   1.93  Santro
# 2264       Manual     Second    18.30  1373.566667  None    NaN   2.95   Etios
# 2325       Manual      First    16.10  1240.447368  None    NaN   4.70   Swift
# 2335       Manual     Second    16.10  1240.447368  None    NaN   1.75   Swift
# 2530    Automatic      First    18.48  2359.428571  None    NaN  17.89       5
# 2542       Manual     Second     0.00  1077.044118  None    NaN   3.15  Santro
# 2623    Automatic     Second    18.48  2359.428571  None    NaN  18.00       5
# 2668       Manual      First    16.10  1240.447368  None    NaN   4.24   Swift
# 2737       Manual      First    12.00  1014.155405  None    NaN   0.70   Wagon
# 2780       Manual      First     0.00  1077.044118  None    NaN   1.60  Santro
# 2842       Manual      First     0.00  1077.044118  None    NaN   3.25  Santro
# 3272    Automatic     Second    18.48  2359.428571  None    NaN  10.50       5
# 3520    Automatic      First    18.48  2359.428571  None    NaN  14.50       5
# 3522       Manual      First     0.00  1077.044118  None    NaN   2.66  Santro
# 3810    Automatic      First    14.00  2216.692308  None    NaN  11.99    CR-V
# 4011       Manual      First    20.30  1172.000000  None    NaN   2.60   Punto
# 4152    Automatic     Second     0.00  2475.719298  None    NaN  16.11   Rover
# 4229       Manual     Second    17.00  1077.044118  None    NaN   1.65  Santro
# 4577    Automatic      Third    18.48  2359.428571  None    NaN  13.85       5
# 4604       Manual      First    16.70  1272.333333  None    NaN   3.15    Jazz
# 4697       Manual      First    15.70  1172.000000  None    NaN   3.93   Punto
# 4712       Manual     Second    17.00  1077.044118  None    NaN   0.90  Santro
# 4952       Manual      First    14.60  1172.000000  None    NaN   1.49   Punto
# 5015       Manual      First    16.10  1240.447368  None    NaN   1.60   Swift
# 5185       Manual      First    16.10  1240.447368  None    NaN   3.65   Swift
# 5270       Manual     Second     0.00  1494.718045  None    NaN   1.85    City

# %%
lst = df['Model'].unique()
for i in lst:
    mean_model = df[df["Model"]==i]['Seats'].mode(0)[0]
    df.update(df[df['Model']==i]['Seats'].fillna(mean_model))

# %%
df[df['Power'].isnull()]
# Out:
#          Name    Location            Year  Kilometers_Driven Fuel_Type  \
# 194     Honda   Ahmedabad            2007              60006    Petrol
# 208    Maruti     Kolkata            2010              42001    Petrol
# 733    Maruti     Chennai            2006              97800    Petrol
# 749      Land      Mumbai            2008              55001    Diesel
# 1294    Honda       Delhi            2009              55005    Petrol
# 1327   Maruti   Hyderabad            2015              50295    Petrol
# 1385    Honda        Pune            2004             115000    Petrol
# 1460     Land  Coimbatore            2008              69078    Petrol
# 2074   Maruti        Pune            2011              24255    Petrol
# 2096  Hyundai  Coimbatore            2004              52146    Petrol
# 2264   Toyota        Pune            2012              24500    Petrol
# 2325   Maruti        Pune            2015              67000    Petrol
# 2335   Maruti      Mumbai            2007              55000    Petrol
# 2530      BMW       Kochi            2014              64158    Diesel
# 2542  Hyundai   Bangalore            2011              65000    Petrol
# 2623      BMW        Pune            2012              95000    Diesel
# 2668   Maruti     Kolkata            2014              32986    Petrol
# 2737   Maruti      Jaipur  less than 2003             200000    Petrol
# 2780  Hyundai        Pune            2009             100000    Petrol
# 2842  Hyundai   Bangalore            2012              43000    Petrol
# 3272      BMW      Mumbai            2008              81000    Diesel
# 3520      BMW       Delhi            2012              90000    Diesel
# 3522  Hyundai       Kochi            2012              66400    Petrol
# 3810    Honda     Kolkata            2013              27000    Petrol
# 4011     Fiat        Pune            2011              45271    Diesel
# 4152     Land      Mumbai            2003              75000    Diesel
# 4229  Hyundai   Bangalore            2005              79000    Petrol
# 4577      BMW       Delhi            2012              72000    Diesel
# 4604    Honda        Pune            2011              98000    Petrol
# 4697     Fiat       Kochi            2017              17941    Petrol
# 4712  Hyundai        Pune            2003              80000    Petrol
# 4952     Fiat     Kolkata            2010              47000    Petrol
# 5015   Maruti       Delhi            2006              63000    Petrol
# 5185   Maruti       Delhi            2012              52000    Petrol
# 5270    Honda   Bangalore  less than 2003              53000    Petrol
#
#      Transmission Owner_Type  Mileage       Engine Power  Seats  Price   Model
# 194        Manual      First     0.00  1494.718045  None    5.0   2.95    City
# 208        Manual      First    16.10  1240.447368  None    5.0   2.11   Swift
# 733        Manual      Third    16.10  1240.447368  None    5.0   1.75   Swift
# 749     Automatic     Second     0.00  2475.719298  None    5.0  26.50   Rover
# 1294       Manual      First    12.80  1494.718045  None    5.0   3.20    City
# 1327       Manual      First    16.10  1240.447368  None    5.0   5.80   Swift
# 1385       Manual     Second     0.00  1494.718045  None    5.0   1.50    City
# 1460       Manual      First     0.00  2475.719298  None    5.0  40.88   Rover
# 2074       Manual      First    16.10  1240.447368  None    5.0   3.15   Swift
# 2096       Manual      First     0.00  1077.044118  None    5.0   1.93  Santro
# 2264       Manual     Second    18.30  1373.566667  None    5.0   2.95   Etios
# 2325       Manual      First    16.10  1240.447368  None    5.0   4.70   Swift
# 2335       Manual     Second    16.10  1240.447368  None    5.0   1.75   Swift
# 2530    Automatic      First    18.48  2359.428571  None    5.0  17.89       5
# 2542       Manual     Second     0.00  1077.044118  None    5.0   3.15  Santro
# 2623    Automatic     Second    18.48  2359.428571  None    5.0  18.00       5
# 2668       Manual      First    16.10  1240.447368  None    5.0   4.24   Swift
# 2737       Manual      First    12.00  1014.155405  None    5.0   0.70   Wagon
# 2780       Manual      First     0.00  1077.044118  None    5.0   1.60  Santro
# 2842       Manual      First     0.00  1077.044118  None    5.0   3.25  Santro
# 3272    Automatic     Second    18.48  2359.428571  None    5.0  10.50       5
# 3520    Automatic      First    18.48  2359.428571  None    5.0  14.50       5
# 3522       Manual      First     0.00  1077.044118  None    5.0   2.66  Santro
# 3810    Automatic      First    14.00  2216.692308  None    5.0  11.99    CR-V
# 4011       Manual      First    20.30  1172.000000  None    NaN   2.60   Punto
# 4152    Automatic     Second     0.00  2475.719298  None    5.0  16.11   Rover
# 4229       Manual     Second    17.00  1077.044118  None    5.0   1.65  Santro
# 4577    Automatic      Third    18.48  2359.428571  None    5.0  13.85       5
# 4604       Manual      First    16.70  1272.333333  None    5.0   3.15    Jazz
# 4697       Manual      First    15.70  1172.000000  None    NaN   3.93   Punto
# 4712       Manual     Second    17.00  1077.044118  None    5.0   0.90  Santro
# 4952       Manual      First    14.60  1172.000000  None    NaN   1.49   Punto
# 5015       Manual      First    16.10  1240.447368  None    5.0   1.60   Swift
# 5185       Manual      First    16.10  1240.447368  None    5.0   3.65   Swift
# 5270       Manual     Second     0.00  1494.718045  None    5.0   1.85    City

# %%
df['Power'] = pd.to_numeric(df['Power'],errors='coerce')

# %%
a = df['Model'].unique()
for i in a:
    r = df[df["Model"]==i]['Power'].astype(float).mean()
    df.update(df[df['Model']==i]['Power'].fillna(r))

# %%
df.dropna(axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# Model                0
# dtype: int64

# %%
plt.figure(figsize=(12,10))
most_cat = df['Name'].value_counts()
sns.barplot(x=most_cat, y=most_cat.index, data=df)
plt.xticks(size=15)
plt.xlabel("Frequency",size=22,c="g")
plt.ylabel("Manufactures",size=22,c="g")
plt.title("Total Cars of all Companies",size=28,c="r")
plt.show()

# %%
df['Name'].value_counts()[df['Name'].value_counts()<5]
# Out:
# Force          3
# ISUZU          2
# Ambassador     1
# Isuzu          1
# Bentley        1
# Lamborghini    1
# Name: Name, dtype: int64

# %%
i = df['Name'].value_counts()[df['Name'].value_counts()<5].index
index = df[df['Name'].isin(i)].index
df.drop(index,axis=0,inplace=True)

# %%
plt.figure(figsize=(8,6))
most_cat = df['Location'].value_counts()
sns.barplot(x=most_cat, y=most_cat.index, data=df)
plt.xticks(size=15)
plt.xlabel("Frequency",size=15,c="g")
plt.ylabel("Location",size=15,c="g")
plt.title("Total Cars Location wise",size=22,c="r")
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=df,y="Name",x="Price")
plt.xlabel("Price",size=18,c="g")
plt.ylabel("Manufactures",size=18,c="g")
plt.title("Price range of differents manufactures",size=25,c="r")
plt.xticks(rotation='vertical',size=15)
plt.show()

# %%
plt.figure(figsize=(12,8)) 
sns.scatterplot(data=df,y="Name",x='Price',color="m")
plt.xticks(rotation='vertical',size=15)
plt.xlabel("Rating",size=15,c="r")
plt.ylabel("Category",size=15,c="r")
plt.title("All Categ with their Rating",size=25,c="red")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=df,x="Fuel_Type",y="Price")
plt.xlabel("Fuel Types",size=17,c="k")
plt.ylabel("Price",size=17,c="k")
plt.title("Fuel Types",size=25,c="red")
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data=df,x="Year",y="Price")
plt.xlabel("Year",size=20,c="g")
plt.ylabel("Price",size=20,c="g")
plt.title("Year vs Price",size=25,c="r")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df,x="Seats")
plt.xlabel("Seats",size=18,c="g")
plt.ylabel("Frequency",size=18,c="g")
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.countplot(data=df,x="Owner_Type")
plt.xlabel("Owner Type",size=15,c="r")
plt.ylabel("Frequency",size=15,c="r")
plt.subplot(1,2,2)
labels =df['Owner_Type'].value_counts(sort = True).index
sizes = df['Owner_Type'].value_counts(sort = True)
plt.pie(sizes, labels=labels,autopct='%1.1f%%', shadow=True, startangle=270)
plt.title('Total % of Owner',size = 25,c="r")
plt.show()

# %%
df.describe()
# Out:
#        Kilometers_Driven      Mileage       Engine        Power        Seats  \
# count       5.974000e+03  5974.000000  5974.000000  5974.000000  5974.000000
# mean        5.865187e+04    18.166691  1619.134961   112.648435     5.274021
# std         9.148420e+04     4.548538   594.935278    53.187367     0.782620
# min         1.710000e+02     0.000000   624.000000    34.200000     2.000000
# 25%         3.400000e+04    15.260000  1198.000000    75.000000     5.000000
# 50%         5.300000e+04    18.160000  1493.000000    93.700000     5.000000
# 75%         7.300000e+04    21.100000  1982.500000   138.100000     5.000000
# max         6.500000e+06    33.540000  5461.000000   550.000000     8.000000
#
#              Price
# count  5974.000000
# mean      9.473658
# std      11.090805
# min       0.440000
# 25%       3.500000
# 50%       5.650000
# 75%       9.957500
# max     160.000000

# %%
col = ['Kilometers_Driven','Power','Mileage','Engine'] 
plt.figure(figsize=(18,12))
for i,v in enumerate(col):
    print(i,v)
    plt.subplot(3,2,i+1)
    sns.boxplot(x=v, data=df,color='red')
plt.show()
# Out:
# 0 Kilometers_Driven
# 1 Power
# 2 Mileage
# 3 Engine

# %%
df.drop(df[df['Kilometers_Driven']>300000].index,inplace=True,axis=0)
df.drop(df[df['Power']>480].index,inplace=True,axis=0)

# %%
col = ['Kilometers_Driven','Power','Mileage','Engine'] 
plt.figure(figsize=(18,12))
for i,v in enumerate(col):
    print(i,v)
    plt.subplot(3,2,i+1)
    sns.boxplot(x=v, data=df,color='green')
plt.show()
# Out:
# 0 Kilometers_Driven
# 1 Power
# 2 Mileage
# 3 Engine

# %%
plt.figure(figsize=(11,7))
plt.subplot(1,1,1)
sns.distplot(df['Price'],color='r',kde_kws={'linewidth':3,'color':'b'});
plt.show()

# %%
col = ['Kilometers_Driven','Mileage','Engine',"Price"] 
plt.figure(figsize=(18,12))
for i,v in enumerate(col):
    print(i,v)
    plt.subplot(3,2,i+1)
    sns.distplot(x=df[v],color='g')
plt.show()
# Out:
# 0 Kilometers_Driven
# 1 Mileage
# 2 Engine
# 3 Price

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=df,y="Price",x='Location',hue='Fuel_Type')
plt.xlabel("Location",size=15,c="r")
plt.ylabel("Price",size=15,c="r")
plt.title("Effect of fuel type on Car price for location",size=25,c="red")
plt.show()

# %%
plt.figure(figsize=(16,6))
sns.barplot(data=df,y="Price",x='Name',hue='Fuel_Type')
plt.xlabel("Location",size=15,c="r")
plt.ylabel("Price",size=15,c="r")
plt.xticks(rotation="vertical",size=10)
plt.title("Effect of fuel type on Price of differents brands",size=25,c="red")
plt.show()

# %%
col = ['Kilometers_Driven','Mileage','Engine',"Power"] 
plt.figure(figsize=(18,12))
for i,v in enumerate(col):
    print(i,v)
    plt.subplot(3,2,i+1)
    sns.scatterplot(x=df[v],y=df['Price'],color='purple')
plt.show()
# Out:
# 0 Kilometers_Driven
# 1 Mileage
# 2 Engine
# 3 Power

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=df,y="Price",x='Location',hue='Owner_Type')
plt.xlabel("Location",size=15,c="red")
plt.ylabel("Price",size=15,c="red")
plt.show()

# %%
plt.figure(figsize=(16,6))
sns.barplot(data=df,y="Price",x='Name',hue='Transmission')
plt.xlabel("Location",size=15,c="red")
plt.ylabel("Price",size=15,c="red")
plt.xticks(rotation="vertical",size=10)
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df[["Price","Kilometers_Driven","Power","Mileage","Engine","Seats"]].corr(), annot=True,linewidths=.5,fmt='.1f')
plt.title("Correlation Graph",c="r",size=25)
plt.show()

# %%
df.drop(['Mileage','Seats','Engine','Transmission'],axis=1,inplace=True)

# %%
df['Car'] = df['Name'].astype(str) + " " + df['Model']
df
# Out:
#            Name    Location  Year  Kilometers_Driven Fuel_Type Owner_Type  \
# 0        Maruti      Mumbai  2010              72000       CNG      First
# 1       Hyundai        Pune  2015              41000    Diesel      First
# 2         Honda     Chennai  2011              46000    Petrol      First
# 3        Maruti     Chennai  2012              87000    Diesel      First
# 4          Audi  Coimbatore  2013              40670    Diesel     Second
# ...         ...         ...   ...                ...       ...        ...
# 6014     Maruti       Delhi  2014              27365    Diesel      First
# 6015    Hyundai      Jaipur  2015             100000    Diesel      First
# 6016   Mahindra      Jaipur  2012              55000    Diesel     Second
# 6017     Maruti     Kolkata  2013              46000    Petrol      First
# 6018  Chevrolet   Hyderabad  2011              47000    Diesel      First
#
#        Power  Price   Model             Car
# 0      58.16   1.75   Wagon    Maruti Wagon
# 1     126.20  12.50   Creta   Hyundai Creta
# 2      88.70   4.50    Jazz      Honda Jazz
# 3      88.76   6.00  Ertiga   Maruti Ertiga
# 4     140.80  17.74      A4         Audi A4
# ...      ...    ...     ...             ...
# 6014   74.00   4.75   Swift    Maruti Swift
# 6015   71.00   4.00   Xcent   Hyundai Xcent
# 6016  112.00   2.90    Xylo   Mahindra Xylo
# 6017   67.10   2.65   Wagon    Maruti Wagon
# 6018   57.60   2.50    Beat  Chevrolet Beat
#
# [5963 rows x 10 columns]

# %%
df.drop(['Name','Model'],axis=1,inplace=True)

# %%
df = df[['Car','Location','Year','Kilometers_Driven','Owner_Type','Fuel_Type','Power','Price']]
df
# Out:
#                  Car    Location  Year  Kilometers_Driven Owner_Type  \
# 0       Maruti Wagon      Mumbai  2010              72000      First
# 1      Hyundai Creta        Pune  2015              41000      First
# 2         Honda Jazz     Chennai  2011              46000      First
# 3      Maruti Ertiga     Chennai  2012              87000      First
# 4            Audi A4  Coimbatore  2013              40670     Second
# ...              ...         ...   ...                ...        ...
# 6014    Maruti Swift       Delhi  2014              27365      First
# 6015   Hyundai Xcent      Jaipur  2015             100000      First
# 6016   Mahindra Xylo      Jaipur  2012              55000     Second
# 6017    Maruti Wagon     Kolkata  2013              46000      First
# 6018  Chevrolet Beat   Hyderabad  2011              47000      First
#
#      Fuel_Type   Power  Price
# 0          CNG   58.16   1.75
# 1       Diesel  126.20  12.50
# 2       Petrol   88.70   4.50
# 3       Diesel   88.76   6.00
# 4       Diesel  140.80  17.74
# ...        ...     ...    ...
# 6014    Diesel   74.00   4.75
# 6015    Diesel   71.00   4.00
# 6016    Diesel  112.00   2.90
# 6017    Petrol   67.10   2.65
# 6018    Diesel   57.60   2.50
#
# [5963 rows x 8 columns]

# %%
df['Car'].unique
# Out:
# <bound method Series.unique of 0         Maruti Wagon
# 1        Hyundai Creta
# 2           Honda Jazz
# 3        Maruti Ertiga
# 4              Audi A4
#              ...
# 6014      Maruti Swift
# 6015     Hyundai Xcent
# 6016     Mahindra Xylo
# 6017      Maruti Wagon
# 6018    Chevrolet Beat
# Name: Car, Length: 5963, dtype: object>

# %%
lst = df['Car'].unique()
no_models= []
for i in lst:
    df1=df[df['Car']==i]
    no_models.append(len(df1))

# %%
dic = dict(zip(list(lst),no_models))

# %%
sort_orders = sorted(dic.items(), key=lambda x: x[1])
for i in sort_orders:
    print(i[0], i[1])
# Out:
# Mini Countryman 1
# Mini Clubman 1
# Porsche Boxster 1
# Mahindra XUV300 1
# Volkswagen Beetle 1
# Volkswagen Tiguan 1
# Nissan Evalia 1
# Mitsubishi Montero 1
# Tata Venture 1
# Toyota Platinum 1
# Mercedes-Benz CLS-Class 1
# Ford Classic 1
# Datsun Redi 1
# Ford Mustang 1
# Ford Fusion 1
# Mercedes-Benz SL-Class 1
# Maruti Versa 1
# Honda WR-V 1
# Mercedes-Benz SLC 2
# Audi RS5 2
# Renault Lodgy 2
# Audi A8 2
# Nissan Teana 2
# Volvo S80 2
# Mitsubishi Cedia 2
# Mercedes-Benz GLS 2
# Mahindra Renault 2
# Mitsubishi Outlander 2
# Chevrolet Captiva 2
# Fiat Punto 2
# Mahindra Logan 2
# Chevrolet Tavera 2
# Volvo XC90 2
# Mitsubishi Lancer 2
# BMW Z4 2
# Nissan X-Trail 3
# Mercedes-Benz C-Class 3
# BMW 1 3
# Mahindra NuvoSport 3
# Jaguar XE 3
# Tata Xenon 3
# Honda BR-V 3
# Renault Captur 3
# Maruti S-Cross 3
# Audi TT 3
# Mercedes-Benz SLK-Class 3
# Renault Koleos 3
# Toyota Qualis 3
# Audi A7 3
# Ford Freestyle 3
# Maruti Grand 3
# Tata Nexon 3
# Honda WRV 4
# Volvo V40 4
# Mahindra Verito 4
# Hyundai Tucson 4
# Audi A3 4
# Tata Hexa 4
# Fiat Avventura 4
# Ford Aspire 4
# Tata Bolt 4
# Volkswagen CrossPolo 4
# Renault Fluence 4
# Mercedes-Benz R-Class 4
# Fiat Grande 5
# Tata Sumo 5
# Honda BRV 5
# Mahindra Quanto 5
# Maruti Esteem 5
# Jaguar XJ 5
# Tata Tigor 5
# Porsche Cayenne 5
# Renault Scala 5
# Renault Pulse 5
# Mercedes-Benz S-Class 5
# Mahindra Thar 6
# Datsun GO 6
# Skoda Yeti 6
# Maruti Ignis 6
# Datsun redi-GO 6
# Volvo XC60 6
# BMW X6 6
# Hyundai Sonata 6
# Maruti S 7
# BMW 6 7
# Volvo S60 7
# Mercedes-Benz GLC 8
# Mercedes-Benz A 8
# Chevrolet Sail 8
# Volkswagen Passat 8
# Tata New 8
# Porsche Panamera 8
# Chevrolet Enjoy 9
# Tata Safari 9
# Mahindra TUV 9
# Mercedes-Benz S 10
# Chevrolet Spark 10
# Hyundai Getz 10
# Skoda Fabia 11
# Mercedes-Benz GL-Class 11
# Toyota Camry 11
# Tata Tiago 11
# Mercedes-Benz B 12
# Chevrolet Optra 12
# Mercedes-Benz GLE 12
# Maruti 800 12
# Fiat Linea 12
# Mahindra Ssangyong 13
# Mercedes-Benz CLA 13
# BMW 7 13
# Mahindra KUV 14
# BMW X3 14
# Ford Ikon 14
# Chevrolet Aveo 14
# Hyundai Elite 14
# Mahindra Bolero 15
# Jeep Compass 15
# Tata Manza 16
# Honda Mobilio 16
# Hyundai Santa 17
# Maruti A-Star 17
# Maruti Eeco 18
# Hyundai Accent 18
# Mercedes-Benz GLA 18
# Chevrolet Cruze 18
# Volkswagen Ameo 19
# Mitsubishi Pajero 20
# Maruti Omni 20
# Tata Zest 21
# Mahindra Xylo 21
# Hyundai Elantra 22
# Mercedes-Benz M-Class 23
# BMW X5 23
# Volkswagen Jetta 23
# Mini Cooper 24
# Maruti Dzire 24
# Tata Nano 25
# Nissan Terrano 26
# Honda Accord 26
# Nissan Sunny 26
# Honda CR-V 27
# Audi Q3 27
# Maruti Zen 29
# Skoda Laura 29
# Jaguar XF 30
# Skoda Octavia 30
# Audi Q5 30
# Tata Indigo 31
# Honda Civic 32
# BMW X1 32
# Nissan Micra 33
# Maruti SX4 37
# Audi Q7 38
# Ford Endeavour 38
# Tata Indica 40
# Renault KWID 40
# Ford Fiesta 40
# Ford EcoSport 42
# Maruti Vitara 43
# Chevrolet Beat 46
# Skoda Rapid 47
# Audi A6 49
# Skoda Superb 49
# Ford Ecosport 53
# Honda Jazz 58
# Maruti Celerio 58
# Hyundai Xcent 59
# Land Rover 60
# Honda Brio 60
# Hyundai EON 60
# Toyota Etios 61
# Mahindra Scorpio 61
# Maruti Baleno 63
# Maruti Ritz 64
# Toyota Corolla 68
# BMW 5 68
# Maruti Ciaz 71
# Maruti Ertiga 75
# Hyundai Santro 75
# Audi A4 77
# Renault Duster 83
# Mercedes-Benz E-Class 88
# Hyundai Creta 93
# Mercedes-Benz New 94
# BMW 3 98
# Ford Figo 101
# Toyota Fortuner 101
# Volkswagen Vento 106
# Honda Amaze 106
# Mahindra XUV500 113
# Maruti Alto 143
# Maruti Wagon 149
# Volkswagen Polo 151
# Hyundai Grand 152
# Hyundai i10 154
# Toyota Innova 162
# Hyundai Verna 170
# Hyundai i20 245
# Honda City 269
# Maruti Swift 351

# %%
sortedDict = dict( sorted(dic.items(), key=lambda x: x[0].lower()) )
for k,v in sortedDict.items():
    print('{}:{}'.format(k,v))
# Out:
# Audi A3:4
# Audi A4:77
# Audi A6:49
# Audi A7:3
# Audi A8:2
# Audi Q3:27
# Audi Q5:30
# Audi Q7:38
# Audi RS5:2
# Audi TT:3
# BMW 1:3
# BMW 3:98
# BMW 5:68
# BMW 6:7
# BMW 7:13
# BMW X1:32
# BMW X3:14
# BMW X5:23
# BMW X6:6
# BMW Z4:2
# Chevrolet Aveo:14
# Chevrolet Beat:46
# Chevrolet Captiva:2
# Chevrolet Cruze:18
# Chevrolet Enjoy:9
# Chevrolet Optra:12
# Chevrolet Sail:8
# Chevrolet Spark:10
# Chevrolet Tavera:2
# Datsun GO:6
# Datsun Redi:1
# Datsun redi-GO:6
# Fiat Avventura:4
# Fiat Grande:5
# Fiat Linea:12
# Fiat Punto:2
# Ford Aspire:4
# Ford Classic:1
# Ford Ecosport:53
# Ford EcoSport:42
# Ford Endeavour:38
# Ford Fiesta:40
# Ford Figo:101
# Ford Freestyle:3
# Ford Fusion:1
# Ford Ikon:14
# Ford Mustang:1
# Honda Accord:26
# Honda Amaze:106
# Honda BR-V:3
# Honda Brio:60
# Honda BRV:5
# Honda City:269
# Honda Civic:32
# Honda CR-V:27
# Honda Jazz:58
# Honda Mobilio:16
# Honda WR-V:1
# Honda WRV:4
# Hyundai Accent:18
# Hyundai Creta:93
# Hyundai Elantra:22
# Hyundai Elite:14
# Hyundai EON:60
# Hyundai Getz:10
# Hyundai Grand:152
# Hyundai i10:154
# Hyundai i20:245
# Hyundai Santa:17
# Hyundai Santro:75
# Hyundai Sonata:6
# Hyundai Tucson:4
# Hyundai Verna:170
# Hyundai Xcent:59
# Jaguar XE:3
# Jaguar XF:30
# Jaguar XJ:5
# Jeep Compass:15
# Land Rover:60
# Mahindra Bolero:15
# Mahindra KUV:14
# Mahindra Logan:2
# Mahindra NuvoSport:3
# Mahindra Quanto:5
# Mahindra Renault:2
# Mahindra Scorpio:61
# Mahindra Ssangyong:13
# Mahindra Thar:6
# Mahindra TUV:9
# Mahindra Verito:4
# Mahindra XUV300:1
# Mahindra XUV500:113
# Mahindra Xylo:21
# Maruti 800:12
# Maruti A-Star:17
# Maruti Alto:143
# Maruti Baleno:63
# Maruti Celerio:58
# Maruti Ciaz:71
# Maruti Dzire:24
# Maruti Eeco:18
# Maruti Ertiga:75
# Maruti Esteem:5
# Maruti Grand:3
# Maruti Ignis:6
# Maruti Omni:20
# Maruti Ritz:64
# Maruti S:7
# Maruti S-Cross:3
# Maruti Swift:351
# Maruti SX4:37
# Maruti Versa:1
# Maruti Vitara:43
# Maruti Wagon:149
# Maruti Zen:29
# Mercedes-Benz A:8
# Mercedes-Benz B:12
# Mercedes-Benz C-Class:3
# Mercedes-Benz CLA:13
# Mercedes-Benz CLS-Class:1
# Mercedes-Benz E-Class:88
# Mercedes-Benz GL-Class:11
# Mercedes-Benz GLA:18
# Mercedes-Benz GLC:8
# Mercedes-Benz GLE:12
# Mercedes-Benz GLS:2
# Mercedes-Benz M-Class:23
# Mercedes-Benz New:94
# Mercedes-Benz R-Class:4
# Mercedes-Benz S:10
# Mercedes-Benz S-Class:5
# Mercedes-Benz SL-Class:1
# Mercedes-Benz SLC:2
# Mercedes-Benz SLK-Class:3
# Mini Clubman:1
# Mini Cooper:24
# Mini Countryman:1
# Mitsubishi Cedia:2
# Mitsubishi Lancer:2
# Mitsubishi Montero:1
# Mitsubishi Outlander:2
# Mitsubishi Pajero:20
# Nissan Evalia:1
# Nissan Micra:33
# Nissan Sunny:26
# Nissan Teana:2
# Nissan Terrano:26
# Nissan X-Trail:3
# Porsche Boxster:1
# Porsche Cayenne:5
# Porsche Panamera:8
# Renault Captur:3
# Renault Duster:83
# Renault Fluence:4
# Renault Koleos:3
# Renault KWID:40
# Renault Lodgy:2
# Renault Pulse:5
# Renault Scala:5
# Skoda Fabia:11
# Skoda Laura:29
# Skoda Octavia:30
# Skoda Rapid:47
# Skoda Superb:49
# Skoda Yeti:6
# Tata Bolt:4
# Tata Hexa:4
# Tata Indica:40
# Tata Indigo:31
# Tata Manza:16
# Tata Nano:25
# Tata New:8
# Tata Nexon:3
# Tata Safari:9
# Tata Sumo:5
# Tata Tiago:11
# Tata Tigor:5
# Tata Venture:1
# Tata Xenon:3
# Tata Zest:21
# Toyota Camry:11
# Toyota Corolla:68
# Toyota Etios:61
# Toyota Fortuner:101
# Toyota Innova:162
# Toyota Platinum:1
# Toyota Qualis:3
# Volkswagen Ameo:19
# Volkswagen Beetle:1
# Volkswagen CrossPolo:4
# Volkswagen Jetta:23
# Volkswagen Passat:8
# Volkswagen Polo:151
# Volkswagen Tiguan:1
# Volkswagen Vento:106
# Volvo S60:7
# Volvo S80:2
# Volvo V40:4
# Volvo XC60:6
# Volvo XC90:2

# %%
len(df['Car'].value_counts()[df['Car'].value_counts()<10])
# Out:
# 95

# %%
df['Car'].value_counts()[df['Car'].value_counts()<10]
# Out:
# Tata Safari          9
# Mahindra TUV         9
# Chevrolet Enjoy      9
# Chevrolet Sail       8
# Volkswagen Passat    8
#                     ..
# Nissan Evalia        1
# Mini Countryman      1
# Volkswagen Tiguan    1
# Volkswagen Beetle    1
# Honda WR-V           1
# Name: Car, Length: 95, dtype: int64

# %%
l = df['Car'].value_counts()[df['Car'].value_counts()<10].index
df[df['Car'].isin(l)]
# Out:
#                         Car    Location  Year  Kilometers_Driven Owner_Type  \
# 21                 Maruti S   Bangalore  2015              55392     Second
# 28                Honda WRV       Kochi  2018              37430      First
# 49            Mahindra Thar      Jaipur  2012              75800     Second
# 58           Nissan X-Trail   Hyderabad  2010             121812      First
# 67    Mercedes-Benz C-Class  Coimbatore  2019              15369      First
# ...                     ...         ...   ...                ...        ...
# 5928     Mahindra NuvoSport  Coimbatore  2018              37323     Second
# 5982              Tata Hexa      Jaipur  2016              39000      First
# 5990               Tata New        Pune  2008              86000      Third
# 5999              Tata Bolt     Chennai  2016              10000      First
# 6008       Porsche Panamera   Hyderabad  2013              40000     Second
#
#      Fuel_Type   Power  Price
# 21      Diesel   88.50   8.25
# 28      Petrol   88.70   9.90
# 49      Diesel  105.00   5.50
# 58      Diesel  147.60   7.75
# 67      Diesel  194.00  35.67
# ...        ...     ...    ...
# 5928    Diesel  100.00   7.29
# 5982    Diesel  153.86  13.50
# 5990    Diesel  138.00   0.60
# 5999    Petrol   88.70   4.00
# 6008    Diesel  300.00  45.00
#
# [350 rows x 8 columns]

# %%
df.drop(df[df['Car'].isin(l)].index,inplace=True,axis=0)

# %%
df_new = df.copy()

# %%
df[['Car','Location','Year','Owner_Type','Fuel_Type']].nunique()
# Out:
# Car           105
# Location       11
# Year           18
# Owner_Type      3
# Fuel_Type       3
# dtype: int64

# %%
df1=df.copy()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
lst = ['Car','Location','Fuel_Type']

# %%
for i in lst:
    le = LabelEncoder()
    df[i]=le.fit_transform(df[i])

# %%
df
# Out:
#       Car  Location  Year  Kilometers_Driven Owner_Type  Fuel_Type   Power  \
# 0      67         9  2010              72000      First          0   58.16
# 1      32        10  2015              41000      First          1  126.20
# 2      29         2  2011              46000      First          2   88.70
# 3      61         2  2012              87000      First          1   88.76
# 4       0         3  2013              40670     Second          1  140.80
# ...   ...       ...   ...                ...        ...        ...     ...
# 6014   65         4  2014              27365      First          1   74.00
# 6015   41         6  2015             100000      First          1   71.00
# 6016   52         6  2012              55000     Second          1  112.00
# 6017   67         8  2013              46000      First          2   67.10
# 6018   12         5  2011              47000      First          1   57.60
#
#       Price
# 0      1.75
# 1     12.50
# 2      4.50
# 3      6.00
# 4     17.74
# ...     ...
# 6014   4.75
# 6015   4.00
# 6016   2.90
# 6017   2.65
# 6018   2.50
#
# [5613 rows x 8 columns]

# %%
df['Owner_Type'].value_counts()
# Out:
# First     4612
# Second     900
# Third      101
# Name: Owner_Type, dtype: int64

# %%
dic = {'First':2,'Second':1,'Third':0}

# %%
df['Year'].value_counts()
# Out:
# 2014              754
# 2015              704
# 2016              700
# 2013              607
# 2012              556
# 2017              535
# 2011              434
# 2010              316
# 2018              268
# 2009              187
# 2008              161
# 2007              113
# 2019               87
# 2006               74
# 2005               53
# 2004               27
# less than 2003     26
# 2003               11
# Name: Year, dtype: int64

# %%
dic1 = {'2019':17,"2018":16,"2017":15,"2016":14,"2015":13,"2014":12,"2013":11,"2012":10,"2011":9,"2010":8,"2009":7,"2008":6,"2007":5,"2006":4,"2005":3,"2004":2,"2003":1,"less than 2003":0 }

# %%
df['Owner_Type']=df['Owner_Type'].map(dic)
df['Year']=df['Year'].map(dic1)
df
# Out:
#       Car  Location  Year  Kilometers_Driven  Owner_Type  Fuel_Type   Power  \
# 0      67         9     8              72000           2          0   58.16
# 1      32        10    13              41000           2          1  126.20
# 2      29         2     9              46000           2          2   88.70
# 3      61         2    10              87000           2          1   88.76
# 4       0         3    11              40670           1          1  140.80
# ...   ...       ...   ...                ...         ...        ...     ...
# 6014   65         4    12              27365           2          1   74.00
# 6015   41         6    13             100000           2          1   71.00
# 6016   52         6    10              55000           1          1  112.00
# 6017   67         8    11              46000           2          2   67.10
# 6018   12         5     9              47000           2          1   57.60
#
#       Price
# 0      1.75
# 1     12.50
# 2      4.50
# 3      6.00
# 4     17.74
# ...     ...
# 6014   4.75
# 6015   4.00
# 6016   2.90
# 6017   2.65
# 6018   2.50
#
# [5613 rows x 8 columns]

# %%
X = df.drop("Price",axis=1) 
Y= df['Price']    
Y
# Out:
# 0        1.75
# 1       12.50
# 2        4.50
# 3        6.00
# 4       17.74
#         ...
# 6014     4.75
# 6015     4.00
# 6016     2.90
# 6017     2.65
# 6018     2.50
# Name: Price, Length: 5613, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=1)
X_train
# Out:
#       Car  Location  Year  Kilometers_Driven  Owner_Type  Fuel_Type   Power
# 3626   21         3    13              92885           2          1   68.00
# 3946   65         5    14              30000           2          1   74.00
# 3421   97         0    12              59000           2          2  138.03
# 4846    0         5    11              52000           2          1  147.51
# 5420    5         9    14              19000           1          1  190.00
# ...   ...       ...   ...                ...         ...        ...     ...
# 979    67        10    12              51000           2          2   67.04
# 5570   83         2    10              80000           2          1  108.45
# 4280   84        10    13              28000           2          2   53.30
# 256   100        10    15              43000           2          1  147.80
# 5534   80         9    13              34895           2          2   75.94
#
# [3929 rows x 7 columns]

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train, Y_train)
y_pred= lr.predict(X_test)
print("Accuracy on Traing set: ",lr.score(X_train,Y_train))
print("Accuracy on Testing set: ",lr.score(X_test,Y_test))
# Out:
# Accuracy on Traing set:  0.6779073313110087
# Accuracy on Testing set:  0.6861011272608684

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=100)

# %%
rf.fit(X_train, Y_train)
y_pred= rf.predict(X_test)

print("Accuracy on Traing set: ",rf.score(X_train,Y_train))
print("Accuracy on Testing set: ",rf.score(X_test,Y_test))
# Out:
# Accuracy on Traing set:  0.9828906805646119
# Accuracy on Testing set:  0.9098054846913903

# %%
from sklearn import metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error

print("\t\tError Table")
print('Mean Absolute Error      : ', metrics.mean_absolute_error(Y_test, y_pred))
print('Mean Squared  Error      : ', metrics.mean_squared_error(Y_test, y_pred))
print('Root Mean Squared  Error : ', np.sqrt(metrics.mean_squared_error(Y_test, y_pred)))
print('R Squared Error          : ', metrics.r2_score(Y_test, y_pred))
# Out:
# 		Error Table
# Mean Absolute Error      :  1.5015620779606382
# Mean Squared  Error      :  10.128651257595795
# Root Mean Squared  Error :  3.182554203402637
# R Squared Error          :  0.9098054846913903

# %%
from sklearn.ensemble import ExtraTreesRegressor
selection= ExtraTreesRegressor()
selection.fit(X,Y)
# Out:
# ExtraTreesRegressor()

# %%
plt.figure(figsize = (12,8))
feat_importances = pd.Series(selection.feature_importances_, index=X.columns)
feat_importances.nlargest(20).plot(kind='barh')
plt.show()

# %%
residual=Y_test-y_pred
print(residual)
# Out:
# 3665    0.0986
# 2604    2.1921
# 1551    0.0106
# 2313   -1.1148
# 2375    0.2773
#          ...
# 5150   -0.7450
# 2183   -1.6403
# 1674    0.1687
# 192     0.4421
# 2761   -5.7653
# Name: Price, Length: 1684, dtype: float64

# %%
dic={'Y_pred' :y_pred,'residual' : residual}
df1=pd.DataFrame(dic)
df1.head()
# Out:
#        Y_pred  residual
# 3665   3.3114    0.0986
# 2604  32.8079    2.1921
# 1551   2.3394    0.0106
# 2313   4.3648   -1.1148
# 2375   1.7727    0.2773

# %%
df1['Y_Test']=Y_test

# %%
sns.scatterplot(data=df1,x='Y_pred',y='residual')
plt.show()

# %%
sns.histplot(residual)
plt.show()

# %%
residual.skew()
# Out:
# 2.5715966876865366

# %%
sns.scatterplot(data=df1,y='Y_pred',x='Y_Test')
plt.show()

# %%
dic={'Y_pred' :y_pred,'residual' : residual}
df1=pd.DataFrame(dic)
df1.head()
# Out:
#        Y_pred  residual
# 3665   3.3114    0.0986
# 2604  32.8079    2.1921
# 1551   2.3394    0.0106
# 2313   4.3648   -1.1148
# 2375   1.7727    0.2773

# %%
sns.scatterplot(data=df1,x='Y_pred',y='residual')
plt.show()
